# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/PDFMiner_Example/blob/main/Merge_Export_getting_pdf_tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install camelot-py
# Out:
# Collecting camelot-py
#   Downloading camelot_py-0.11.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from camelot-py) (5.2.0)
# Requirement already satisfied: click>=6.7 in /usr/local/lib/python3.10/dist-packages (from camelot-py) (8.1.7)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from camelot-py) (1.25.2)
# Requirement already satisfied: openpyxl>=2.5.8 in /usr/local/lib/python3.10/dist-packages (from camelot-py) (3.1.2)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from camelot-py) (2.0.3)
# Collecting pdfminer.six>=20200726 (from camelot-py)
#   Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 19.7 MB/s eta 0:00:00
# Collecting pypdf>=3.0.0 (from camelot-py)
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from camelot-py) (0.9.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=2.5.8->camelot-py) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->camelot-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->camelot-py) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->camelot-py) (2024.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six>=20200726->camelot-py) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six>=20200726->camelot-py) (42.0.7)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf>=3.0.0->camelot-py) (4.11.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py) (1.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23.4->camelot-py) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py) (2.22)
# Installing collected packages: pypdf, pdfminer.six, camelot-py
# Successfully installed camelot-py-0.11.0 pdfminer.six-20231228 pypdf-4.2.0

# %%
# !apt install ghostscript python3-tk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-tk is already the newest version (3.10.8-1~22.04).
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 libgs9 libgs9-common libidn12 libijs-0.35
#   libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x poppler-utils
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript libgs9 libgs9-common libidn12
#   libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 10 newly installed, 0 to remove and 45 not upgraded.
# Need to get 16.7 MB of archives.
# After this operation, 63.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.6 [751 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.6 [5,031 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.6 [49.4 kB]
# Fetched 16.7 MB in 2s (7,497 kB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../0-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../1-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../2-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../3-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../4-libgs9-common_9.55.0~dfsg1-0ubuntu5.6_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.6) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../5-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../6-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../7-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../8-libgs9_9.55.0~dfsg1-0ubuntu5.6_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.6) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../9-ghostscript_9.55.0~dfsg1-0ubuntu5.6_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.6) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.6) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.6) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.6) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install ghostscript
# Out:
# Collecting ghostscript
#   Downloading ghostscript-0.7-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: setuptools>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from ghostscript) (67.7.2)
# Installing collected packages: ghostscript
# Successfully installed ghostscript-0.7

# %%
import camelot
import pandas as pd

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data  WWF_I_Appendix_N_3_Table.pdf

# %% [markdown]
# https://camelot-py.readthedocs.io/en/master/user/quickstart.html#read-the-pdf

# %%
# extract all the tables in the PDF file
all_pdfs = camelot.read_pdf("WWF_I_Appendix_N_3_Table.pdf",pages='0,1,2,3')
# nothing here
all_pdfs[0]
all_pdfs
# Out:
# <TableList n=6>

# %%
table_0 = all_pdfs[0].df
table_0

table_1 = all_pdfs[1].df
table_1

table_2 = all_pdfs[2].df
table_2

table_3 = all_pdfs[3].df
table_3

table_4 = all_pdfs[4].df
table_4

table_5 = all_pdfs[5].df
table_5
# Out:
#            0               1                         2                    3  \
# 0     Region        Division     Location/Sub-division          Name of VDC
# 1
# 2     Hazara           Siran              Tangli RF 11                  Ahl
# 3     Hazara           Siran         Massar RF 12 (ii)                Jabba
# 4     Hazara           Siran        Massar RF 12 (iii)                Jabba
# 5     Hazara           Siran  Shinkiari Massar RF 8(1)            Shinkiari
# 6     Hazara           Siran            Paryai RF 2(i)           Stana gali
# 7     Hazara       Thor Ghar     Aleema Banda Sari C 3          Aleema sari
# 8   Malakand          Alpuri                    Alpuri               Machar
# 9   Malakand          Alpuri                    Alpuri  wahab Khel \nKotkay
# 10  Malakand          Alpuri                    Karora              Damorai
# 11  Malakand          Alpuri                    Alpuri             Lilownai
# 12  Malakand          Alpuri                    Karora         Darkali Upal
# 13  Malakand          Alpuri                    Karora             Chakesar
# 14  Malakand           Bunir                     Dagar            Kat Kalla
# 15  Malakand           Bunir                    Chamla                Nagri
# 16  Malakand         Chitral                     Booni        Golain Payeen
# 17  Malakand         Chitral                   Chitral                Birir
# 18  Malakand         Chitral                   Chitral           Jughor Gol
# 19  Malakand         Chitral                   Chitral           Sahan Ayun
# 20  Malakand         Chitral                   Chitral           Sahan Ayun
# 21  Malakand         Chitral               Drosh North               Kaldam
# 22  Malakand  Dir \nKohistan                    Patrak              Chamkot
# 23  Malakand           Kalam             Behrain North              Balakot
# 24  Malakand           Kalam             Behrain South      Piya Chancharai
# 25  Malakand           Kalam             Behrain South             Dabargai
# 26  Malakand       Lower Dir                Timargirah          Amlook dara
# 27  Malakand       Lower Dir                Timargirah               Gumbat
# 28  Malakand       Lower Dir                Timargirah               Nasapa
#
#                4              5           6                       7
# 0     Coordinats                                               Zone
# 1              N              E  Ele. \n(m)
# 2   34 31 \n44.3   73 09 \n24.6        1631  Sub-Tropical Chir Pine
# 3   34 26 \n54.2   73 18 \n39.2        1102  Sub-Tropical Chir Pine
# 4   34 26 \n50.9   73 18 \n56.7        1141  Sub-Tropical Chir Pine
# 5   34 28 \n48.3   73 18 \n04.2        1381  Sub-Tropical Chir Pine
# 6   34 36 \n28.4   73 18 \n04.8        2017         Moist  Temprate
# 7   34 45 \n12.1   72 51 \n55.1        1208         Moist  Temprate
# 8      34 54 9.2   72 37 \n20.3        1874         Moist  Temprate
# 9   34 53 \n04.8   72 36 \n42.9        1800         Moist  Temprate
# 10  34 59 \n58.8   72 45 \n21.7        1519         Moist  Temprate
# 11  34 55 \n56.4   72 33 \n26.4        1521         Moist  Temprate
# 12  34 49 \n53.9   72 48 \n11.1        1597         Moist  Temprate
# 13  34 49 \n08.4   72 47 \n57.3        1582         Moist  Temprate
# 14  34 35 \n13.5   72 22 \n33.8        1332  Sub-Tropical Chir Pine
# 15  34 22 \n28.6   72 39 \n55.4         775  Sub-Tropical Chir Pine
# 16  35 54 \n19.1   72 00 \n18.3        2420           Dry Temperate
# 17  35 83 \n34.7   71 42 \n32.0        1737           Dry Temperate
# 18  35 49 \n26.6   71 48 \n57.2        1853           Dry Temperate
# 19  35 42' \n14"  71 43' \n8.3"        2492           Dry Temperate
# 20  35 42' \n14"  71 43' \n8.3"        2492           Dry Temperate
# 21  35 34 \n34.4   71 49 \n27.2        1501           Dry Temperate
# 22  35 23 \n.031   72 02 \n.110        2071           Dry Temperate
# 23  35 19 \n.807   72 36 \n.186        2211           Dry Temperate
# 24  35 06 \n.932   72 33 \n.020        2276         Moist  Temprate
# 25  35 09 \n.473   72 35 \n.435        2000         Moist  Temprate
# 26  34 42 \n.742   71 52 \n.933        1070  Sub-Tropical Chir Pine
# 27  34 43 \n.577   71 51 \n.829        1021  Sub-Tropical Chir Pine
# 28  34 43 \n.517   71 54 \n.522        1045  Sub-Tropical Chir Pine

# %%
merged_tables = pd.concat([table_0, table_1, table_2, table_3, table_4, table_5])
merged_tables
# Out:
#            0          1                      2                     3  \
# 0     Region   Division  Location/Sub-division           Name of VDC
# 1
# 2   Malakand  Lower Dir               Chakdara        Kotaira Osakai
# 3   Malakand  Lower Dir               Chakdara  Osakay Mianz \nKalay
# 4   Malakand  Lower Dir               Chakdara   Landi Cham \nOsakay
# ..       ...        ...                    ...                   ...
# 24  Malakand      Kalam          Behrain South       Piya Chancharai
# 25  Malakand      Kalam          Behrain South              Dabargai
# 26  Malakand  Lower Dir             Timargirah           Amlook dara
# 27  Malakand  Lower Dir             Timargirah                Gumbat
# 28  Malakand  Lower Dir             Timargirah                Nasapa
#
#                4             5           6                       7
# 0     Coordinats                                              Zone
# 1              N             E  Ele. \n(m)
# 2   34 42 \n.170  71 57 \n.691        1113  Sub-Tropical Chir Pine
# 3   34 42 \n.077  71 57 \n.426        1280  Sub-Tropical Chir Pine
# 4   34 42 \n.434  71 56 \n.539        1355  Sub-Tropical Chir Pine
# ..           ...           ...         ...                     ...
# 24  35 06 \n.932  72 33 \n.020        2276         Moist  Temprate
# 25  35 09 \n.473  72 35 \n.435        2000         Moist  Temprate
# 26  34 42 \n.742  71 52 \n.933        1070  Sub-Tropical Chir Pine
# 27  34 43 \n.577  71 51 \n.829        1021  Sub-Tropical Chir Pine
# 28  34 43 \n.517  71 54 \n.522        1045  Sub-Tropical Chir Pine
#
# [124 rows x 8 columns]

# %%
# @title 0

from matplotlib import pyplot as plt
import seaborn as sns
merged_tables.groupby(0).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
merged_tables.to_csv('Appendix_N_3.csv')

# %% [markdown]
# Second Table Rip

# %%
# extract all the tables in the PDF file
all_pdfs_x = camelot.read_pdf("WWF_btap_monitoring_report_phase_ix.pdf", pages='118, 119, 120, 121, 122')
# nothing here
all_pdfs_x[0]
all_pdfs_x
# Out:
# <TableList n=5>

# %%
table_0x = all_pdfs_x[0].df
table_0x

table_1x = all_pdfs_x[1].df
table_1x

table_2x = all_pdfs_x[2].df
table_2x

table_3x = all_pdfs_x[3].df
table_3x

table_4x = all_pdfs_x[4].df
table_4x
# Out:
#        0                1                      2                        3   \
# 0  Region  Forest division  Range/ sub-\ndivision           Location/ Site
# 1   South         Peshawar               Peshawar  Military Farm \nKheshki
# 2   South         Peshawar              Charsadda                   Nisata
# 3   South            Kohat                  Karak              Thapi Karak
# 4   South            Kohat                  Karak             Shobli Banda
# 5   South            Bannu               L Marwat           Wanda Sher dil
# 6   South            Total
# 7   South              Avg
#
#                       4                               5         6   \
# 0  Area \nclaimed \n(ha)  Area ha  \n(Monitoring \nTeam)  Variance
# 1                     11                              15         4
# 2                      5                             4.8      -0.2
# 3                   4.85                            5.29      0.44
# 4                     20                            20.4       0.4
# 5                     40                           41.06      1.06
# 6                  80.85                           86.55       5.7
# 7                  16.17                           17.31
#
#                                       7   \
# 0  Total plants \nplanted \n(Per record)
# 1                                  12000
# 2                                   5160
# 3                                   5200
# 4                                  21500
# 5                                   4300
# 6                                  48160
# 7
#
#                                              8         9                  10  \
# 0  Total plants \nplanted \n(Monitoring \nTeam)  Variance  Survival \nRate %
# 1                                         12833       833              68.38
# 2                                          4640      -520              54.00
# 3                                          5438       238              61.19
# 4                                         20000     -1500              83.15
# 5                                          4400       100              93.16
# 6                                         47311
# 7                                                                      71.98
#
#                      11
# 0  Avg \nSpacing \n(ft)
# 1                  9.52
# 2               10.2333
# 3                 9.875
# 4                 10.75
# 5                 9.795
# 6
# 7                 10.03

# %%
merged_tablesx = pd.concat([table_0x, table_1x, table_2x, table_3x, table_4x])
merged_tablesx
# Out:
#         0         1                      2               3   \
# 0   Region  Division  Location/Sub-division     Name of VDC
# 1    South    Mardan                 Gadoon        Mazghund
# 2    South    Mardan                 Gadoon            Utal
# 3    South     Kohat                  Kohat       Nak Banda
# 4    South     Kohat                  Hango   Khrasha Banda
# ..     ...       ...                    ...             ...
# 3    South     Kohat                  Karak     Thapi Karak
# 4    South     Kohat                  Karak    Shobli Banda
# 5    South     Bannu               L Marwat  Wanda Sher dil
# 6    South     Total
# 7    South       Avg
#
#                            4                            5   \
# 0                        Zone  No of \nClosures \nverified
# 1      Sub-Tropical Chir Pine                            4
# 2      Sub-Tropical Chir Pine                            6
# 3   Sub-Tropical Broad Leaved                            2
# 4   Sub-Tropical Broad Leaved                            1
# ..                        ...                          ...
# 3                        4.85                         5.29
# 4                          20                         20.4
# 5                          40                        41.06
# 6                       80.85                        86.55
# 7                       16.17                        17.31
#
#                      6                                       7   \
# 0   Total \narea \n(ha)  Area \ntraversed \nfor plot \nsampling
# 1                    80                                      80
# 2                   120                                     120
# 3                    80                                      40
# 4                    40                                      40
# ..                  ...                                     ...
# 3                  0.44                                    5200
# 4                   0.4                                   21500
# 5                  1.06                                    4300
# 6                   5.7                                   48160
# 7
#
#                       8                     9   \
# 0   Avg. Reg. \nper Plot  Avg. \nReg. per \nha
# 1                   52.4                  5240
# 2                   58.5                  5850
# 3                   27.4                  2740
# 4                   31.4                  3140
# ..                   ...                   ...
# 3                   5438                   238
# 4                  20000                 -1500
# 5                   4400                   100
# 6                  47311
# 7
#
#                                       10     11
# 0   Total \nRegeneration \nin total area    NaN
# 1                                 419200    NaN
# 2                                 702000    NaN
# 3                                 219200    NaN
# 4                                 125600    NaN
# ..                                   ...    ...
# 3                                  61.19  9.875
# 4                                  83.15  10.75
# 5                                  93.16  9.795
# 6
# 7                                  71.98  10.03
#
# [105 rows x 12 columns]

# %%
merged_tablesx.to_csv('Appendix_I.csv')

# %% [markdown]
# Join tables

# %% [markdown]
# # Bring in appendix N and I and clean and adjust

# %%
app_N = pd.read_csv("Appendix_N_cleaned.csv")
#

# %%
app_I = pd.read_csv("Appendix_I_cleaned.csv")
#app_I

# %%
Join_tables = app_N.merge(app_I, on="Name of VDC", how = 'inner')
#Join_tables

# %%
Join_tables['Coordinates_N'] = Join_tables['Coordinates_N'].str.replace('\n', '')
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x  \
# 0      1    34 42 .170  71 57 \n.691  Malakand  Lower Dir
# 1      4    34 42 .863  71 56 \n.444  Malakand  Lower Dir
# 2      5    34 42 44.6  71 54 \n59.8  Malakand  Lower Dir
# 3      6    34 42 45.2  71 55 \n15.1  Malakand  Lower Dir
# 4      7    34 42 41.5  71 55 \n30.9  Malakand  Lower Dir
# ..   ...           ...           ...       ...        ...
# 88    83    35 06 .932  72 33 \n.020  Malakand      Kalam
# 89    84    35 09 .473  72 35 \n.435  Malakand      Kalam
# 90    85    34 42 .742  71 52 \n.933  Malakand  Lower Dir
# 91    86    34 43 .577  71 51 \n.829  Malakand  Lower Dir
# 92    87    34 43 .517  71 54 \n.522  Malakand  Lower Dir
#
#    Location/Sub-division_x      Name of VDC  Ele. \n(m)  \
# 0                 Chakdara   Kotaira Osakai        1113
# 1                 Chakdara     Dagai Osakay        1286
# 2               Timargirah    Sarai Bala-01        1175
# 3               Timargirah   Sarai Bala- 02        1291
# 4               Timargirah    Sarai bala-03        1393
# ..                     ...              ...         ...
# 88           Behrain South  Piya Chancharai        2276
# 89           Behrain South         Dabargai        2000
# 90              Timargirah      Amlook dara        1070
# 91              Timargirah           Gumbat        1021
# 92              Timargirah           Nasapa        1045
#
#                     Zone_x  ID_y  Region_y Division_y Location/Sub-division_y  \
# 0   Sub-Tropical Chir Pine    26  Malakand  Lower Dir                Chakdara
# 1   Sub-Tropical Chir Pine     2  Malakand  Lower Dir                Chakdara
# 2   Sub-Tropical Chir Pine     3  Malakand  Lower Dir              Timargirah
# 3   Sub-Tropical Chir Pine     4  Malakand  Lower Dir              Timargirah
# 4   Sub-Tropical Chir Pine     5  Malakand  Lower Dir              Timargirah
# ..                     ...   ...       ...        ...                     ...
# 88          Moist Temprate    21  Malakand      Kalam           Behrain South
# 89          Moist Temprate    22  Malakand      Kalam           Behrain South
# 90  Sub-Tropical Chir Pine    23  Malakand  Lower Dir              Timargirah
# 91  Sub-Tropical Chir Pine    24  Malakand  Lower Dir              Timargirah
# 92  Sub-Tropical Chir Pine    25  Malakand  Lower Dir              Timargirah
#
#                     Zone_y  No of \nClosures \nverified  Total \narea \n(ha)  \
# 0   Sub-Tropical Chir Pine                          1.0                 46.0
# 1   Sub-Tropical Chir Pine                          1.0                 29.0
# 2   Sub-Tropical Chir Pine                          1.0                 23.0
# 3   Sub-Tropical Chir Pine                          1.0                 29.0
# 4   Sub-Tropical Chir Pine                          1.0                  5.0
# ..                     ...                          ...                  ...
# 88         Moist Temperate                          2.0                320.0
# 89         Moist Temperate                          2.0                300.0
# 90  Sub-Tropical Chir Pine                          1.0                 36.0
# 91  Sub-Tropical Chir Pine                          1.0                 20.0
# 92  Sub-Tropical Chir Pine                          1.0                 37.0
#
#     Area \ntraversed \nfor plot \nsampling  Avg. Reg. \nper Plot  \
# 0                                       46                 25.00
# 1                                       29                 15.15
# 2                                       23                 26.35
# 3                                       29                 35.67
# 4                                        5                 19.40
# ..                                     ...                   ...
# 88                                     186                  1.84
# 89                                     182                  2.98
# 90                                      36                 25.62
# 91                                      20                 28.57
# 92                                      37                 25.74
#
#     Avg. \nReg. per \nha  Total \nRegeneration \nin total area
# 0                2500.18                             115008.28
# 1                1515.23                              43941.67
# 2                2634.59                              60595.57
# 3                3566.76                             103436.04
# 4                1939.71                               9698.55
# ..                   ...                                   ...
# 88                183.80                              58816.00
# 89                298.39                              89517.00
# 90               2562.10                              92235.60
# 91               2857.06                              57141.20
# 92               2574.10                              95241.70
#
# [93 rows x 20 columns]

# %%
Join_tables['Coordinates_S'] = Join_tables['Coordinates_S'].str.replace('\n', '')
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir
# ..   ...           ...           ...       ...        ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir
#
#    Location/Sub-division_x      Name of VDC  Ele. \n(m)  \
# 0                 Chakdara   Kotaira Osakai        1113
# 1                 Chakdara     Dagai Osakay        1286
# 2               Timargirah    Sarai Bala-01        1175
# 3               Timargirah   Sarai Bala- 02        1291
# 4               Timargirah    Sarai bala-03        1393
# ..                     ...              ...         ...
# 88           Behrain South  Piya Chancharai        2276
# 89           Behrain South         Dabargai        2000
# 90              Timargirah      Amlook dara        1070
# 91              Timargirah           Gumbat        1021
# 92              Timargirah           Nasapa        1045
#
#                     Zone_x  ID_y  Region_y Division_y Location/Sub-division_y  \
# 0   Sub-Tropical Chir Pine    26  Malakand  Lower Dir                Chakdara
# 1   Sub-Tropical Chir Pine     2  Malakand  Lower Dir                Chakdara
# 2   Sub-Tropical Chir Pine     3  Malakand  Lower Dir              Timargirah
# 3   Sub-Tropical Chir Pine     4  Malakand  Lower Dir              Timargirah
# 4   Sub-Tropical Chir Pine     5  Malakand  Lower Dir              Timargirah
# ..                     ...   ...       ...        ...                     ...
# 88          Moist Temprate    21  Malakand      Kalam           Behrain South
# 89          Moist Temprate    22  Malakand      Kalam           Behrain South
# 90  Sub-Tropical Chir Pine    23  Malakand  Lower Dir              Timargirah
# 91  Sub-Tropical Chir Pine    24  Malakand  Lower Dir              Timargirah
# 92  Sub-Tropical Chir Pine    25  Malakand  Lower Dir              Timargirah
#
#                     Zone_y  No of \nClosures \nverified  Total \narea \n(ha)  \
# 0   Sub-Tropical Chir Pine                          1.0                 46.0
# 1   Sub-Tropical Chir Pine                          1.0                 29.0
# 2   Sub-Tropical Chir Pine                          1.0                 23.0
# 3   Sub-Tropical Chir Pine                          1.0                 29.0
# 4   Sub-Tropical Chir Pine                          1.0                  5.0
# ..                     ...                          ...                  ...
# 88         Moist Temperate                          2.0                320.0
# 89         Moist Temperate                          2.0                300.0
# 90  Sub-Tropical Chir Pine                          1.0                 36.0
# 91  Sub-Tropical Chir Pine                          1.0                 20.0
# 92  Sub-Tropical Chir Pine                          1.0                 37.0
#
#     Area \ntraversed \nfor plot \nsampling  Avg. Reg. \nper Plot  \
# 0                                       46                 25.00
# 1                                       29                 15.15
# 2                                       23                 26.35
# 3                                       29                 35.67
# 4                                        5                 19.40
# ..                                     ...                   ...
# 88                                     186                  1.84
# 89                                     182                  2.98
# 90                                      36                 25.62
# 91                                      20                 28.57
# 92                                      37                 25.74
#
#     Avg. \nReg. per \nha  Total \nRegeneration \nin total area
# 0                2500.18                             115008.28
# 1                1515.23                              43941.67
# 2                2634.59                              60595.57
# 3                3566.76                             103436.04
# 4                1939.71                               9698.55
# ..                   ...                                   ...
# 88                183.80                              58816.00
# 89                298.39                              89517.00
# 90               2562.10                              92235.60
# 91               2857.06                              57141.20
# 92               2574.10                              95241.70
#
# [93 rows x 20 columns]

# %% [markdown]
# # Fix the header names

# %%
Join_tables = Join_tables.drop(['ID_y', 'Region_y', 'Division_y', 'Location/Sub-division_y', 'Zone_y'], axis=1)
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir
# ..   ...           ...           ...       ...        ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir
#
#    Location/Sub-division_x      Name of VDC  Ele. \n(m)  \
# 0                 Chakdara   Kotaira Osakai        1113
# 1                 Chakdara     Dagai Osakay        1286
# 2               Timargirah    Sarai Bala-01        1175
# 3               Timargirah   Sarai Bala- 02        1291
# 4               Timargirah    Sarai bala-03        1393
# ..                     ...              ...         ...
# 88           Behrain South  Piya Chancharai        2276
# 89           Behrain South         Dabargai        2000
# 90              Timargirah      Amlook dara        1070
# 91              Timargirah           Gumbat        1021
# 92              Timargirah           Nasapa        1045
#
#                     Zone_x  No of \nClosures \nverified  Total \narea \n(ha)  \
# 0   Sub-Tropical Chir Pine                          1.0                 46.0
# 1   Sub-Tropical Chir Pine                          1.0                 29.0
# 2   Sub-Tropical Chir Pine                          1.0                 23.0
# 3   Sub-Tropical Chir Pine                          1.0                 29.0
# 4   Sub-Tropical Chir Pine                          1.0                  5.0
# ..                     ...                          ...                  ...
# 88          Moist Temprate                          2.0                320.0
# 89          Moist Temprate                          2.0                300.0
# 90  Sub-Tropical Chir Pine                          1.0                 36.0
# 91  Sub-Tropical Chir Pine                          1.0                 20.0
# 92  Sub-Tropical Chir Pine                          1.0                 37.0
#
#     Area \ntraversed \nfor plot \nsampling  Avg. Reg. \nper Plot  \
# 0                                       46                 25.00
# 1                                       29                 15.15
# 2                                       23                 26.35
# 3                                       29                 35.67
# 4                                        5                 19.40
# ..                                     ...                   ...
# 88                                     186                  1.84
# 89                                     182                  2.98
# 90                                      36                 25.62
# 91                                      20                 28.57
# 92                                      37                 25.74
#
#     Avg. \nReg. per \nha  Total \nRegeneration \nin total area
# 0                2500.18                             115008.28
# 1                1515.23                              43941.67
# 2                2634.59                              60595.57
# 3                3566.76                             103436.04
# 4                1939.71                               9698.55
# ..                   ...                                   ...
# 88                183.80                              58816.00
# 89                298.39                              89517.00
# 90               2562.10                              92235.60
# 91               2857.06                              57141.20
# 92               2574.10                              95241.70
#
# [93 rows x 15 columns]

# %%
Join_tables = Join_tables.rename(columns={'Location/Sub-division_x':'Sub_division'})
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x   Sub_division  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir       Chakdara
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir       Chakdara
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir     Timargirah
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir     Timargirah
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir     Timargirah
# ..   ...           ...           ...       ...        ...            ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam  Behrain South
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam  Behrain South
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir     Timargirah
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir     Timargirah
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir     Timargirah
#
#         Name of VDC  Ele. \n(m)                  Zone_x  \
# 0    Kotaira Osakai        1113  Sub-Tropical Chir Pine
# 1      Dagai Osakay        1286  Sub-Tropical Chir Pine
# 2     Sarai Bala-01        1175  Sub-Tropical Chir Pine
# 3    Sarai Bala- 02        1291  Sub-Tropical Chir Pine
# 4     Sarai bala-03        1393  Sub-Tropical Chir Pine
# ..              ...         ...                     ...
# 88  Piya Chancharai        2276          Moist Temprate
# 89         Dabargai        2000          Moist Temprate
# 90      Amlook dara        1070  Sub-Tropical Chir Pine
# 91           Gumbat        1021  Sub-Tropical Chir Pine
# 92           Nasapa        1045  Sub-Tropical Chir Pine
#
#     No of \nClosures \nverified  Total \narea \n(ha)  \
# 0                           1.0                 46.0
# 1                           1.0                 29.0
# 2                           1.0                 23.0
# 3                           1.0                 29.0
# 4                           1.0                  5.0
# ..                          ...                  ...
# 88                          2.0                320.0
# 89                          2.0                300.0
# 90                          1.0                 36.0
# 91                          1.0                 20.0
# 92                          1.0                 37.0
#
#     Area \ntraversed \nfor plot \nsampling  Avg. Reg. \nper Plot  \
# 0                                       46                 25.00
# 1                                       29                 15.15
# 2                                       23                 26.35
# 3                                       29                 35.67
# 4                                        5                 19.40
# ..                                     ...                   ...
# 88                                     186                  1.84
# 89                                     182                  2.98
# 90                                      36                 25.62
# 91                                      20                 28.57
# 92                                      37                 25.74
#
#     Avg. \nReg. per \nha  Total \nRegeneration \nin total area
# 0                2500.18                             115008.28
# 1                1515.23                              43941.67
# 2                2634.59                              60595.57
# 3                3566.76                             103436.04
# 4                1939.71                               9698.55
# ..                   ...                                   ...
# 88                183.80                              58816.00
# 89                298.39                              89517.00
# 90               2562.10                              92235.60
# 91               2857.06                              57141.20
# 92               2574.10                              95241.70
#
# [93 rows x 15 columns]

# %%
Join_tables = Join_tables.rename(columns={'Ele. \n(m)':'Elev_m', 'No of \nClosures \nverified': 'No_of_Closures_verified ', 'Total \narea \n(ha) Area': 'Total_area_ha', 'area \n(ha) Area \ntraversed \nfor plot \nsampling': 'Area_traversed_for_plot_sampling','Avg. Reg. \nper Plot':'Avg_Reg_Plot','Avg. \nReg. per \nha':'Avg_Reg_per_ha','Total \nRegeneration \nin total area':'Total_Regeneration_total_area'})
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x   Sub_division  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir       Chakdara
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir       Chakdara
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir     Timargirah
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir     Timargirah
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir     Timargirah
# ..   ...           ...           ...       ...        ...            ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam  Behrain South
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam  Behrain South
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir     Timargirah
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir     Timargirah
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir     Timargirah
#
#         Name of VDC  Elev_m                  Zone_x  No_of_Closures_verified   \
# 0    Kotaira Osakai    1113  Sub-Tropical Chir Pine                       1.0
# 1      Dagai Osakay    1286  Sub-Tropical Chir Pine                       1.0
# 2     Sarai Bala-01    1175  Sub-Tropical Chir Pine                       1.0
# 3    Sarai Bala- 02    1291  Sub-Tropical Chir Pine                       1.0
# 4     Sarai bala-03    1393  Sub-Tropical Chir Pine                       1.0
# ..              ...     ...                     ...                       ...
# 88  Piya Chancharai    2276          Moist Temprate                       2.0
# 89         Dabargai    2000          Moist Temprate                       2.0
# 90      Amlook dara    1070  Sub-Tropical Chir Pine                       1.0
# 91           Gumbat    1021  Sub-Tropical Chir Pine                       1.0
# 92           Nasapa    1045  Sub-Tropical Chir Pine                       1.0
#
#     Total \narea \n(ha)  Area \ntraversed \nfor plot \nsampling  Avg_Reg_Plot  \
# 0                  46.0                                      46         25.00
# 1                  29.0                                      29         15.15
# 2                  23.0                                      23         26.35
# 3                  29.0                                      29         35.67
# 4                   5.0                                       5         19.40
# ..                  ...                                     ...           ...
# 88                320.0                                     186          1.84
# 89                300.0                                     182          2.98
# 90                 36.0                                      36         25.62
# 91                 20.0                                      20         28.57
# 92                 37.0                                      37         25.74
#
#     Avg_Reg_per_ha  Total_Regeneration_total_area
# 0          2500.18                      115008.28
# 1          1515.23                       43941.67
# 2          2634.59                       60595.57
# 3          3566.76                      103436.04
# 4          1939.71                        9698.55
# ..             ...                            ...
# 88          183.80                       58816.00
# 89          298.39                       89517.00
# 90         2562.10                       92235.60
# 91         2857.06                       57141.20
# 92         2574.10                       95241.70
#
# [93 rows x 15 columns]

# %%
Join_tables = Join_tables.rename(columns={'Total \narea \n(ha)':'Total_area_ha', 'Area \ntraversed \nfor plot \nsampling': 'Area_traversed_for_plot_sampling'})
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x   Sub_division  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir       Chakdara
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir       Chakdara
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir     Timargirah
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir     Timargirah
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir     Timargirah
# ..   ...           ...           ...       ...        ...            ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam  Behrain South
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam  Behrain South
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir     Timargirah
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir     Timargirah
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir     Timargirah
#
#         Name of VDC  Elev_m                  Zone_x  No_of_Closures_verified   \
# 0    Kotaira Osakai    1113  Sub-Tropical Chir Pine                       1.0
# 1      Dagai Osakay    1286  Sub-Tropical Chir Pine                       1.0
# 2     Sarai Bala-01    1175  Sub-Tropical Chir Pine                       1.0
# 3    Sarai Bala- 02    1291  Sub-Tropical Chir Pine                       1.0
# 4     Sarai bala-03    1393  Sub-Tropical Chir Pine                       1.0
# ..              ...     ...                     ...                       ...
# 88  Piya Chancharai    2276          Moist Temprate                       2.0
# 89         Dabargai    2000          Moist Temprate                       2.0
# 90      Amlook dara    1070  Sub-Tropical Chir Pine                       1.0
# 91           Gumbat    1021  Sub-Tropical Chir Pine                       1.0
# 92           Nasapa    1045  Sub-Tropical Chir Pine                       1.0
#
#     Total_area_ha  Area_traversed_for_plot_sampling  Avg_Reg_Plot  \
# 0            46.0                                46         25.00
# 1            29.0                                29         15.15
# 2            23.0                                23         26.35
# 3            29.0                                29         35.67
# 4             5.0                                 5         19.40
# ..            ...                               ...           ...
# 88          320.0                               186          1.84
# 89          300.0                               182          2.98
# 90           36.0                                36         25.62
# 91           20.0                                20         28.57
# 92           37.0                                37         25.74
#
#     Avg_Reg_per_ha  Total_Regeneration_total_area
# 0          2500.18                      115008.28
# 1          1515.23                       43941.67
# 2          2634.59                       60595.57
# 3          3566.76                      103436.04
# 4          1939.71                        9698.55
# ..             ...                            ...
# 88          183.80                       58816.00
# 89          298.39                       89517.00
# 90         2562.10                       92235.60
# 91         2857.06                       57141.20
# 92         2574.10                       95241.70
#
# [93 rows x 15 columns]

# %%
Join_tables = Join_tables.rename(columns={'Name of VDC':'VDC'})
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x   Sub_division  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir       Chakdara
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir       Chakdara
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir     Timargirah
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir     Timargirah
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir     Timargirah
# ..   ...           ...           ...       ...        ...            ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam  Behrain South
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam  Behrain South
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir     Timargirah
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir     Timargirah
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir     Timargirah
#
#                 VDC  Elev_m                  Zone_x  No_of_Closures_verified   \
# 0    Kotaira Osakai    1113  Sub-Tropical Chir Pine                       1.0
# 1      Dagai Osakay    1286  Sub-Tropical Chir Pine                       1.0
# 2     Sarai Bala-01    1175  Sub-Tropical Chir Pine                       1.0
# 3    Sarai Bala- 02    1291  Sub-Tropical Chir Pine                       1.0
# 4     Sarai bala-03    1393  Sub-Tropical Chir Pine                       1.0
# ..              ...     ...                     ...                       ...
# 88  Piya Chancharai    2276          Moist Temprate                       2.0
# 89         Dabargai    2000          Moist Temprate                       2.0
# 90      Amlook dara    1070  Sub-Tropical Chir Pine                       1.0
# 91           Gumbat    1021  Sub-Tropical Chir Pine                       1.0
# 92           Nasapa    1045  Sub-Tropical Chir Pine                       1.0
#
#     Total_area_ha  Area_traversed_for_plot_sampling  Avg_Reg_Plot  \
# 0            46.0                                46         25.00
# 1            29.0                                29         15.15
# 2            23.0                                23         26.35
# 3            29.0                                29         35.67
# 4             5.0                                 5         19.40
# ..            ...                               ...           ...
# 88          320.0                               186          1.84
# 89          300.0                               182          2.98
# 90           36.0                                36         25.62
# 91           20.0                                20         28.57
# 92           37.0                                37         25.74
#
#     Avg_Reg_per_ha  Total_Regeneration_total_area
# 0          2500.18                      115008.28
# 1          1515.23                       43941.67
# 2          2634.59                       60595.57
# 3          3566.76                      103436.04
# 4          1939.71                        9698.55
# ..             ...                            ...
# 88          183.80                       58816.00
# 89          298.39                       89517.00
# 90         2562.10                       92235.60
# 91         2857.06                       57141.20
# 92         2574.10                       95241.70
#
# [93 rows x 15 columns]

# %%
#id_count = pd.Series(range(1,94))
# Join_tables = Join_tables.set_index([id_count, id_count**2])
# Join_tables

# %% [markdown]
# # Switch the Degree Minutes Seconds to Decimal Degrees

# %%
Join_tables['Coordinates_S_Degree'] = Join_tables.Coordinates_S.apply(lambda x: x[:2])

Join_tables['Coordinates_S_Minute'] = Join_tables.Coordinates_S.apply(lambda x: x[3:5])

Join_tables['Coordinates_S_Second'] = Join_tables.Coordinates_S.apply(lambda x: x[7:])

###
Join_tables['Coordinates_N_Degree'] = Join_tables.Coordinates_N.apply(lambda x: x[:2])

Join_tables['Coordinates_N_Minute'] = Join_tables.Coordinates_N.apply(lambda x: x[3:5])

Join_tables['Coordinates_N_Second'] = Join_tables.Coordinates_N.apply(lambda x: x[7:])
###
Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x   Sub_division  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir       Chakdara
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir       Chakdara
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir     Timargirah
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir     Timargirah
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir     Timargirah
# ..   ...           ...           ...       ...        ...            ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam  Behrain South
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam  Behrain South
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir     Timargirah
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir     Timargirah
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir     Timargirah
#
#                 VDC  Elev_m                  Zone_x  No_of_Closures_verified   \
# 0    Kotaira Osakai    1113  Sub-Tropical Chir Pine                       1.0
# 1      Dagai Osakay    1286  Sub-Tropical Chir Pine                       1.0
# 2     Sarai Bala-01    1175  Sub-Tropical Chir Pine                       1.0
# 3    Sarai Bala- 02    1291  Sub-Tropical Chir Pine                       1.0
# 4     Sarai bala-03    1393  Sub-Tropical Chir Pine                       1.0
# ..              ...     ...                     ...                       ...
# 88  Piya Chancharai    2276          Moist Temprate                       2.0
# 89         Dabargai    2000          Moist Temprate                       2.0
# 90      Amlook dara    1070  Sub-Tropical Chir Pine                       1.0
# 91           Gumbat    1021  Sub-Tropical Chir Pine                       1.0
# 92           Nasapa    1045  Sub-Tropical Chir Pine                       1.0
#
#     ...  Area_traversed_for_plot_sampling  Avg_Reg_Plot  Avg_Reg_per_ha  \
# 0   ...                                46         25.00         2500.18
# 1   ...                                29         15.15         1515.23
# 2   ...                                23         26.35         2634.59
# 3   ...                                29         35.67         3566.76
# 4   ...                                 5         19.40         1939.71
# ..  ...                               ...           ...             ...
# 88  ...                               186          1.84          183.80
# 89  ...                               182          2.98          298.39
# 90  ...                                36         25.62         2562.10
# 91  ...                                20         28.57         2857.06
# 92  ...                                37         25.74         2574.10
#
#     Total_Regeneration_total_area  Coordinates_S_Degree Coordinates_S_Minute  \
# 0                       115008.28                    71                   57
# 1                        43941.67                    71                   56
# 2                        60595.57                    71                   54
# 3                       103436.04                    71                   55
# 4                         9698.55                    71                   55
# ..                            ...                   ...                  ...
# 88                       58816.00                    72                   33
# 89                       89517.00                    72                   35
# 90                       92235.60                    71                   52
# 91                       57141.20                    71                   51
# 92                       95241.70                    71                   54
#
#    Coordinates_S_Second Coordinates_N_Degree Coordinates_N_Minute  \
# 0                   691                   34                   42
# 1                   444                   34                   42
# 2                   9.8                   34                   42
# 3                   5.1                   34                   42
# 4                   0.9                   34                   42
# ..                  ...                  ...                  ...
# 88                  020                   35                   06
# 89                  435                   35                   09
# 90                  933                   34                   42
# 91                  829                   34                   43
# 92                  522                   34                   43
#
#    Coordinates_N_Second
# 0                   170
# 1                   863
# 2                   4.6
# 3                   5.2
# 4                   1.5
# ..                  ...
# 88                  932
# 89                  473
# 90                  742
# 91                  577
# 92                  517
#
# [93 rows x 21 columns]

# %%
print("Join_tables before converting")
Join_tables.dtypes
# Out:
# Join_tables before converting
# ID_x                                  int64
# Coordinates_N                        object
# Coordinates_S                        object
# Region_x                             object
# Division_x                           object
# Sub_division                         object
# VDC                                  object
# Elev_m                                int64
# Zone_x                               object
# No_of_Closures_verified             float64
# Total_area_ha                       float64
# Area_traversed_for_plot_sampling      int64
# Avg_Reg_Plot                        float64
# Avg_Reg_per_ha                      float64
# Total_Regeneration_total_area       float64
# Coordinates_S_Degree                 object
# Coordinates_S_Minute                 object
# Coordinates_S_Second                 object
# Coordinates_N_Degree                 object
# Coordinates_N_Minute                 object
# Coordinates_N_Second                 object
# dtype: object

# %%
Join_tables["Coordinates_S_Degree"] = pd.to_numeric(Join_tables.Coordinates_S_Degree, errors='coerce')
Join_tables["Coordinates_S_Minute"] = pd.to_numeric(Join_tables.Coordinates_S_Minute, errors='coerce')
Join_tables["Coordinates_S_Second"] = pd.to_numeric(Join_tables.Coordinates_S_Second, errors='coerce')


Join_tables["Coordinates_N_Degree"] = pd.to_numeric(Join_tables.Coordinates_N_Degree, errors='coerce')
Join_tables["Coordinates_N_Minute"] = pd.to_numeric(Join_tables.Coordinates_N_Minute, errors='coerce')
Join_tables["Coordinates_N_Second"] = pd.to_numeric(Join_tables.Coordinates_N_Second, errors='coerce')

Join_tables.dtypes
# Out:
# ID_x                                  int64
# Coordinates_N                        object
# Coordinates_S                        object
# Region_x                             object
# Division_x                           object
# Sub_division                         object
# VDC                                  object
# Elev_m                                int64
# Zone_x                               object
# No_of_Closures_verified             float64
# Total_area_ha                       float64
# Area_traversed_for_plot_sampling      int64
# Avg_Reg_Plot                        float64
# Avg_Reg_per_ha                      float64
# Total_Regeneration_total_area       float64
# Coordinates_S_Degree                  int64
# Coordinates_S_Minute                  int64
# Coordinates_S_Second                float64
# Coordinates_N_Degree                  int64
# Coordinates_N_Minute                  int64
# Coordinates_N_Second                float64
# dtype: object

# %% [markdown]
# # Lambda function to operate on entire columns

# %%
Join_tables["Coordinates_S_Decimal"] = Join_tables[["Coordinates_S_Degree","Coordinates_S_Minute","Coordinates_S_Minute"]].apply(lambda row: row.values[0] + row.values[1]/60 + row.values[2]/3600, axis=1)

Join_tables["Coordinates_N_Decimal"] = Join_tables[["Coordinates_N_Degree","Coordinates_N_Minute","Coordinates_N_Minute"]].apply(lambda row: row.values[0] + row.values[1]/60 + row.values[2]/3600, axis=1)


Join_tables
# Out:
#     ID_x Coordinates_N Coordinates_S  Region_x Division_x   Sub_division  \
# 0      1    34 42 .170    71 57 .691  Malakand  Lower Dir       Chakdara
# 1      4    34 42 .863    71 56 .444  Malakand  Lower Dir       Chakdara
# 2      5    34 42 44.6    71 54 59.8  Malakand  Lower Dir     Timargirah
# 3      6    34 42 45.2    71 55 15.1  Malakand  Lower Dir     Timargirah
# 4      7    34 42 41.5    71 55 30.9  Malakand  Lower Dir     Timargirah
# ..   ...           ...           ...       ...        ...            ...
# 88    83    35 06 .932    72 33 .020  Malakand      Kalam  Behrain South
# 89    84    35 09 .473    72 35 .435  Malakand      Kalam  Behrain South
# 90    85    34 42 .742    71 52 .933  Malakand  Lower Dir     Timargirah
# 91    86    34 43 .577    71 51 .829  Malakand  Lower Dir     Timargirah
# 92    87    34 43 .517    71 54 .522  Malakand  Lower Dir     Timargirah
#
#                 VDC  Elev_m                  Zone_x  No_of_Closures_verified   \
# 0    Kotaira Osakai    1113  Sub-Tropical Chir Pine                       1.0
# 1      Dagai Osakay    1286  Sub-Tropical Chir Pine                       1.0
# 2     Sarai Bala-01    1175  Sub-Tropical Chir Pine                       1.0
# 3    Sarai Bala- 02    1291  Sub-Tropical Chir Pine                       1.0
# 4     Sarai bala-03    1393  Sub-Tropical Chir Pine                       1.0
# ..              ...     ...                     ...                       ...
# 88  Piya Chancharai    2276          Moist Temprate                       2.0
# 89         Dabargai    2000          Moist Temprate                       2.0
# 90      Amlook dara    1070  Sub-Tropical Chir Pine                       1.0
# 91           Gumbat    1021  Sub-Tropical Chir Pine                       1.0
# 92           Nasapa    1045  Sub-Tropical Chir Pine                       1.0
#
#     ...  Avg_Reg_per_ha  Total_Regeneration_total_area  Coordinates_S_Degree  \
# 0   ...         2500.18                      115008.28                    71
# 1   ...         1515.23                       43941.67                    71
# 2   ...         2634.59                       60595.57                    71
# 3   ...         3566.76                      103436.04                    71
# 4   ...         1939.71                        9698.55                    71
# ..  ...             ...                            ...                   ...
# 88  ...          183.80                       58816.00                    72
# 89  ...          298.39                       89517.00                    72
# 90  ...         2562.10                       92235.60                    71
# 91  ...         2857.06                       57141.20                    71
# 92  ...         2574.10                       95241.70                    71
#
#     Coordinates_S_Minute  Coordinates_S_Second  Coordinates_N_Degree  \
# 0                     57                 691.0                    34
# 1                     56                 444.0                    34
# 2                     54                   9.8                    34
# 3                     55                   5.1                    34
# 4                     55                   0.9                    34
# ..                   ...                   ...                   ...
# 88                    33                  20.0                    35
# 89                    35                 435.0                    35
# 90                    52                 933.0                    34
# 91                    51                 829.0                    34
# 92                    54                 522.0                    34
#
#     Coordinates_N_Minute  Coordinates_N_Second  Coordinates_S_Decimal  \
# 0                     42                 170.0              71.965833
# 1                     42                 863.0              71.948889
# 2                     42                   4.6              71.915000
# 3                     42                   5.2              71.931944
# 4                     42                   1.5              71.931944
# ..                   ...                   ...                    ...
# 88                     6                 932.0              72.559167
# 89                     9                 473.0              72.593056
# 90                    42                 742.0              71.881111
# 91                    43                 577.0              71.864167
# 92                    43                 517.0              71.915000
#
#     Coordinates_N_Decimal
# 0               34.711667
# 1               34.711667
# 2               34.711667
# 3               34.711667
# 4               34.711667
# ..                    ...
# 88              35.101667
# 89              35.152500
# 90              34.711667
# 91              34.728611
# 92              34.728611
#
# [93 rows x 23 columns]

# %% [markdown]
# # Export for QGIS

# %%
Join_tables.to_csv('Appendix_N_and_I_Python_Joined.csv')
